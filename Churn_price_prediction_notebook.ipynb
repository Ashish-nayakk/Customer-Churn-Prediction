# %%
import pandas as pd

# %%
df=pd.read_csv("/content/customer_churn_data.csv")

# %%
df.head(20)
# Out:
#     CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0            1   49    Male       4           88.35  Month-to-Month
# 1            2   43    Male       0           36.67  Month-to-Month
# 2            3   51  Female       2           63.79  Month-to-Month
# 3            4   60  Female       8          102.34        One-Year
# 4            5   42    Male      32           69.01  Month-to-Month
# 5            6   42  Female      16          119.75        Two-Year
# 6            7   60    Male      14           80.32        One-Year
# 7            8   52  Female       6           58.90        One-Year
# 8            9   40  Female      53           49.81        Two-Year
# 9           10   50  Female      10           61.55  Month-to-Month
# 10          11   40  Female       1           63.53  Month-to-Month
# 11          12   40  Female      19           36.18        One-Year
# 12          13   47    Male       2           63.26        Two-Year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1000 non-null   int64
#  1   Age              1000 non-null   int64
#  2   Gender           1000 non-null   object
#  3   Tenure           1000 non-null   int64
#  4   MonthlyCharges   1000 non-null   float64
#  5   ContractType     1000 non-null   object
#  6   InternetService  703 non-null    object
#  7   TotalCharges     1000 non-null   float64
#  8   TechSupport      1000 non-null   object
#  9   Churn            1000 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.3+ KB

# %%
df.isna().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(297)

# %%
df["InternetService"].fillna("")
# Out:
# 0      Fiber Optic
# 1      Fiber Optic
# 2      Fiber Optic
# 3              DSL
# 4
#           ...
# 995    Fiber Optic
# 996
# 997    Fiber Optic
# 998
# 999
# Name: InternetService, Length: 1000, dtype: object

# %%
df["InternetService"]=df["InternetService"].fillna("") #save it as a datfaframe

# %%
df.isna().sum().sum()  # Check if there are still any missing values
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.duplicated()
df.duplicated().sum()  # Check for duplicate rows
# Out:
# np.int64(0)

# %%
df.head()  # Display the first few rows of the DataFrame
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.describe()  # Get a statistical summary of the DataFrame
# Out:
#         CustomerID          Age      Tenure  MonthlyCharges  TotalCharges
# count  1000.000000  1000.000000  1000.00000     1000.000000   1000.000000
# mean    500.500000    44.674000    18.97300       74.391290   1404.364060
# std     288.819436     9.797741    18.89257       25.712083   1571.755048
# min       1.000000    12.000000     0.00000       30.000000      0.000000
# 25%     250.750000    38.000000     5.00000       52.357500    345.217500
# 50%     500.500000    45.000000    13.00000       74.060000    872.870000
# 75%     750.250000    51.000000    26.00000       96.102500   1900.175000
# max    1000.000000    83.000000   122.00000      119.960000  12416.250000

# %%
numeric_columns_data = df.select_dtypes(include=['number'])

# %%
numeric_columns_data.corr()  # Calculate the correlation matrix for numeric columns
# Out:
#                 CustomerID       Age    Tenure  MonthlyCharges  TotalCharges
# CustomerID        1.000000  0.036730 -0.018585       -0.030504     -0.027490
# Age               0.036730  1.000000  0.000472        0.006362     -0.001896
# Tenure           -0.018585  0.000472  1.000000       -0.014552      0.894868
# MonthlyCharges   -0.030504  0.006362 -0.014552        1.000000      0.304893
# TotalCharges     -0.027490 -0.001896  0.894868        0.304893      1.000000

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
df['Churn'].value_counts()  # Count the occurrences of each value in the 'Churn' column
# Out:
# Churn
# Yes    883
# No     117
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df['Churn'].value_counts().plot(kind='bar')  # Plot the value counts of the 'Churn' column as a bar chart
plt.title("Churn Distribution")
plt.xlabel('Churn')
plt.ylabel('Count')
plt.legend(['yes','no'])
plt.show()

# %%
df['Churn'].value_counts().plot(kind='pie')  # Plot the value counts of the 'Churn' column as a pie chart
plt.title("Churn Distribution")
plt.xlabel('Churn')
plt.ylabel('Count')
plt.legend(['yes','no'])
plt.show()

# %%
df.head(5)
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.groupby('Churn')["Tenure"].mean()  # Calculate the mean of each numeric column grouped by 'Churn'
# Out:
# Churn
# No     30.264957
# Yes    17.476784
# Name: Tenure, dtype: float64

# %%
df.groupby(["Churn","Gender"])["Tenure"].mean()
# Out:
# Churn  Gender
# No     Female    30.132353
#        Male      30.448980
# Yes    Female    17.048936
#        Male      17.963680
# Name: Tenure, dtype: float64

# %%
df.groupby('Churn')["MonthlyCharges"].mean()
# Out:
# Churn
# No     62.54641
# Yes    75.96077
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby(["Churn","Gender"])["MonthlyCharges"].mean()
# Out:
# Churn  Gender
# No     Female    65.091912
#        Male      59.013878
# Yes    Female    74.975064
#        Male      77.082518
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby('Churn')["Age"].mean()
# Out:
# Churn
# No     43.487179
# Yes    44.831257
# Name: Age, dtype: float64

# %%
df.groupby(["Churn","Gender"])["Age"].mean()
# Out:
# Churn  Gender
# No     Female    43.838235
#        Male      43.000000
# Yes    Female    45.287234
#        Male      44.312349
# Name: Age, dtype: float64

# %%
df.groupby('ContractType')["MonthlyCharges"].mean().plot(kind='bar')  # Plot the mean of 'MonthlyCharges' grouped by 'ContractType'
plt.xlabel('Contract Type')
plt.ylabel('Average Monthly Charges')
plt.title("Average Monthly Charges by Contract Type")
plt.xticks(rotation=45)
plt.legend(['Month-to-Month', 'One Year', 'Two Year'])
plt.title("Monthly Charges by Contract Type")
plt.legend()
plt.show()

# %%
df.head(10)  # Display the first few rows of the DataFrame again to confirm changes
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
# 5           6   42  Female      16          119.75        Two-Year
# 6           7   60    Male      14           80.32        One-Year
# 7           8   52  Female       6           58.90        One-Year
# 8           9   40  Female      53           49.81        Two-Year
# 9          10   50  Female      10           61.55  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# ...

# %%
plt.hist(df['MonthlyCharges'], bins=20, edgecolor='red')  # Plot a histogram of 'MonthlyCharges'
plt.title("Histogram of monthly charges")
# Out:
# Text(0.5, 1.0, 'Histogram of monthly charges')

# %%
plt.hist(df['Tenure'], bins=20, edgecolor='red')  # Plot a histogram of 'MonthlyCharges'
plt.title("Histogram of Tenure")
# Out:
# Text(0.5, 1.0, 'Histogram of Tenure')

# %%
df.columns  # Display the columns of the DataFrame
df.head(10)  # Display the first few rows of the DataFrame again to confirm changes
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
# 5           6   42  Female      16          119.75        Two-Year
# 6           7   60    Male      14           80.32        One-Year
# 7           8   52  Female       6           58.90        One-Year
# 8           9   40  Female      53           49.81        Two-Year
# 9          10   50  Female      10           61.55  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# ...

# %%
y = df["Churn"]  # Define the target variable
X = df[["CustomerID","Age","Gender","Tenure","MonthlyCharges"]]  # Define the feature set by dropping the target

# %%
X #0 for male,1 for female
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges
# 0             1   49    Male       4           88.35
# 1             2   43    Male       0           36.67
# 2             3   51  Female       2           63.79
# 3             4   60  Female       8          102.34
# 4             5   42    Male      32           69.01
# ..          ...  ...     ...     ...             ...
# 995         996   42    Male      41           37.14
# 996         997   62    Male       9           80.93
# 997         998   51  Female      15          111.72
# 998         999   39    Male      68           65.67
# 999        1000   50    Male       1           56.67
#
# [1000 rows x 5 columns]

# %%
X["Gender"] = X["Gender"].apply(lambda x: 1 if x == "Female" else 0)  # Convert
# Out:
# /tmp/ipython-input-550484223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Gender"] = X["Gender"].apply(lambda x: 1 if x == "Female" else 0)  # Convert

# %%
X.head(10)
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges
# 0           1   49       0       4           88.35
# 1           2   43       0       0           36.67
# 2           3   51       1       2           63.79
# 3           4   60       1       8          102.34
# 4           5   42       0      32           69.01
# 5           6   42       1      16          119.75
# 6           7   60       0      14           80.32
# 7           8   52       1       6           58.90
# 8           9   40       1      53           49.81
# 9          10   50       1      10           61.55

# %%
y
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 995    Yes
# 996    Yes
# 997    Yes
# 998    Yes
# 999    Yes
# Name: Churn, Length: 1000, dtype: object

# %%
y.head(10)
# Out:
# 0    Yes
# 1    Yes
# 2    Yes
# 3    Yes
# 4    Yes
# 5    Yes
# 6    Yes
# 7    Yes
# 8     No
# 9    Yes
# Name: Churn, dtype: object

# %%
type(X["Gender"][0])
# Out:
# numpy.int64

# %%
y["Churn"]=y.apply(lambda x: 1 if x == "Yes" else 0)  # Convert 'Churn' to binary values (1 for Yes, 0 for No)
# Out:
# /tmp/ipython-input-2691532126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["Churn"]=y.apply(lambda x: 1 if x == "Yes" else 0)  # Convert 'Churn' to binary values (1 for Yes, 0 for No)

# %%
type(y["Churn"][0])
# Out:
# numpy.int64

# %%
y
# Out:
# 0                                                      Yes
# 1                                                      Yes
# 2                                                      Yes
# 3                                                      Yes
# 4                                                      Yes
#                                ...
# 996                                                    Yes
# 997                                                    Yes
# 998                                                    Yes
# 999                                                    Yes
# Churn    0      1
# 1      1
# 2      1
# 3      1
# 4      1
#  ...
# Name: Churn, Length: 1001, dtype: object

# %%
X
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges
# 0             1   49       0       4           88.35
# 1             2   43       0       0           36.67
# 2             3   51       1       2           63.79
# 3             4   60       1       8          102.34
# 4             5   42       0      32           69.01
# ..          ...  ...     ...     ...             ...
# 995         996   42       0      41           37.14
# 996         997   62       0       9           80.93
# 997         998   51       1      15          111.72
# 998         999   39       0      68           65.67
# 999        1000   50       0       1           56.67
#
# [1000 rows x 5 columns]

# %%
print(len(X), len(y))
# Out:
# 1000 1001

# %%
print(df.shape)   # rows, cols
# Out:
# (1000, 10)

# %%
# Ensure X and y align
X = df.drop(columns=["CustomerID", "Churn"])  # drop ID and target column
y = df["Churn"]

# Reset index for both
X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

print(len(X), len(y))  # should both be 1000
# Out:
# 1000 1000

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)  # Split the data into training and testing sets

# %%
X
# Out:
#      Age  Gender  Tenure  MonthlyCharges    ContractType InternetService  \
# 0     49    Male       4           88.35  Month-to-Month     Fiber Optic
# 1     43    Male       0           36.67  Month-to-Month     Fiber Optic
# 2     51  Female       2           63.79  Month-to-Month     Fiber Optic
# 3     60  Female       8          102.34        One-Year             DSL
# 4     42    Male      32           69.01  Month-to-Month
# ..   ...     ...     ...             ...             ...             ...
# 995   42    Male      41           37.14  Month-to-Month     Fiber Optic
# 996   62    Male       9           80.93  Month-to-Month
# 997   51  Female      15          111.72  Month-to-Month     Fiber Optic
# 998   39    Male      68           65.67        One-Year
# 999   50    Male       1           56.67  Month-to-Month
#
#      TotalCharges TechSupport
# 0          353.40         Yes
# 1            0.00         Yes
# 2          127.58          No
# ...

# %%
y
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 995    Yes
# 996    Yes
# 997    Yes
# 998    Yes
# 999    Yes
# Name: Churn, Length: 1000, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)  # Split the data into training and testing sets

# %%
X
# Out:
#      Age  Gender  Tenure  MonthlyCharges    ContractType InternetService  \
# 0     49    Male       4           88.35  Month-to-Month     Fiber Optic
# 1     43    Male       0           36.67  Month-to-Month     Fiber Optic
# 2     51  Female       2           63.79  Month-to-Month     Fiber Optic
# 3     60  Female       8          102.34        One-Year             DSL
# 4     42    Male      32           69.01  Month-to-Month
# ..   ...     ...     ...             ...             ...             ...
# 995   42    Male      41           37.14  Month-to-Month     Fiber Optic
# 996   62    Male       9           80.93  Month-to-Month
# 997   51  Female      15          111.72  Month-to-Month     Fiber Optic
# 998   39    Male      68           65.67        One-Year
# 999   50    Male       1           56.67  Month-to-Month
#
#      TotalCharges TechSupport
# 0          353.40         Yes
# 1            0.00         Yes
# 2          127.58          No
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Convert Gender to numeric
X['Gender'] = X['Gender'].apply(lambda x: 1 if x == 'Female' else 0)

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
# Show the full list of features after one-hot encoding
print(X.columns.tolist())
# Out:
# ['Age', 'Gender', 'Tenure', 'MonthlyCharges', 'TotalCharges', 'ContractType_One-Year', 'ContractType_Two-Year', 'InternetService_DSL', 'InternetService_Fiber Optic', 'TechSupport_Yes']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import joblib
joblib.dump(scaler, 'scaler.pkl')  # Save the scaler to a file
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)  # Scale the test set using the fitted scaler

# %%
X_train
# Out:
# array([[ 0.20350187, -1.07532982,  1.90703025, ..., -0.6644106 ,
#         -0.81862454, -1.02788874],
#        [ 1.85004041, -1.07532982, -0.6896416 , ...,  1.50509339,
#         -0.81862454,  0.97286794],
#        [-0.6197674 ,  0.92994724,  1.21811731, ...,  1.50509339,
#         -0.81862454, -1.02788874],
#        ...,
#        [ 1.33549712,  0.92994724, -0.58365499, ..., -0.6644106 ,
#         -0.81862454, -1.02788874],
#        [ 0.51222785,  0.92994724, -0.58365499, ..., -0.6644106 ,
#          1.22156123,  0.97286794],
#        [ 0.92386248, -1.07532982, -0.53066169, ...,  1.50509339,
#         -0.81862454,  0.97286794]])

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions) :
    print("Accuracy score on model is {}".format(accuracy_score(y_test, predictions)) )

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
log_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X
# Out:
#      Age  Gender  Tenure  MonthlyCharges  TotalCharges  ContractType_One-Year  \
# 0     49       0       4           88.35        353.40                  False
# 1     43       0       0           36.67          0.00                  False
# 2     51       1       2           63.79        127.58                  False
# 3     60       1       8          102.34        818.72                   True
# 4     42       0      32           69.01       2208.32                  False
# ..   ...     ...     ...             ...           ...                    ...
# 995   42       0      41           37.14       1522.74                  False
# 996   62       0       9           80.93        728.37                  False
# 997   51       1      15          111.72       1675.80                  False
# 998   39       0      68           65.67       4465.56                   True
# 999   50       0       1           56.67         56.67                  False
#
# ...

# %%
y_pred=log_model.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.92

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid ={
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# %%
gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)

# %%
gridkn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}

# %%
y_pred = gridkn.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.96

# %%
from sklearn.svm import SVC
svm = SVC()

# %%
param_grid ={
    "C" : [0.01,0.1,0.5,1],
    "kernel" : ['linear','poly','rbf']
}

# %%
gridsvc = GridSearchCV(svm, param_grid, cv=5)

# %%
gridsvc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvc.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
y_pred = gridsvc.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.935

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid = {
    "criterion": ["gini", "entropy"],
    "splitter": ["best", "random"],
    "max_depth": [None,10,20,30],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4]
}

# %%
grid_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)

# %%
grid_tree.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_tree.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'splitter': 'best'}

# %%
y_pred = gridsvc.predict(X_test)

# %%
y_pred
# Out:
# array(['No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'Yes',
#        'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No', 'Yes',
# ...

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.935

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model = RandomForestClassifier()

# %%
param_grid = {
    "n_estimators" : [32,64,128,256],
    "max_features" : [2,3,4],
    "bootstrap" : [True, False]
}

# %%
grid_rfc = GridSearchCV(rfc_model, param_grid, cv=5)

# %%
grid_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256]})

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 4, 'n_estimators': 32}

# %%
y_pred = grid_rfc.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.995

# %%
best_model = gridsvc.best_estimator_

# %%
joblib.dump(best_model, "Churn_model.pkl")  # Save the best model to a file
# Out:
# ['Churn_model.pkl']

# %%
X.columns
# Out:
# Index(['Age', 'Gender', 'Tenure', 'MonthlyCharges', 'TotalCharges',
#        'ContractType_One-Year', 'ContractType_Two-Year', 'InternetService_DSL',
#        'InternetService_Fiber Optic', 'TechSupport_Yes'],
#       dtype='object')

# %%
pip install pyngrok

# %%
# %%writefile app.py
from flask import Flask, request, render_template_string
import joblib
import pandas as pd
import numpy as np
import plotly
import plotly.graph_objects as go
import json
from pyngrok import ngrok

app = Flask(__name__)

# Load your files from /content
scaler = joblib.load("/content/scaler.pkl")
model = joblib.load("/content/Churn_model.pkl")

# Load your index.html
with open("/content/index.html", "r") as f:
    html_template = f.read()


@app.route("/", methods=["GET", "POST"])
def home():
    prediction = None
    prob = None
    gauge_json = None

    if request.method == "POST":
        age = int(request.form["age"])
        gender = request.form["gender"]
        tenure = int(request.form["tenure"])
        monthly_charges = float(request.form["monthly_charges"])
        total_charges = float(request.form["total_charges"])
        contract = request.form["contract"]
        internet = request.form["internet"]
        techsupport = request.form["techsupport"]

        gender_value = 1 if gender == "Female" else 0

        input_data = {
            "Age": age,
            "Gender": gender_value,
            "Tenure": tenure,
            "MonthlyCharges": monthly_charges,
            "TotalCharges": total_charges,
            "ContractType_One-Year": 1 if contract == "One year" else 0,
            "ContractType_Two-Year": 1 if contract == "Two year" else 0,
            "InternetService_DSL": 1 if internet == "DSL" else 0,
            "InternetService_Fiber Optic": 1 if internet == "Fiber Optic" else 0,
            "TechSupport_Yes": 1 if techsupport == "Yes" else 0,
        }

        df = pd.DataFrame([input_data])
        df = df.reindex(columns=scaler.feature_names_in_, fill_value=0)

        X_scaled = scaler.transform(df)
        prediction = model.predict(X_scaled)[0]

        if hasattr(model, "predict_proba"):
            prob = model.predict_proba(X_scaled)[0][1] * 100
        else:
            score = model.decision_function(X_scaled)[0]
            prob = 100 / (1 + np.exp(-score))

        result = "Churn" if prediction == 1 else "Not Churn"

        fig = go.Figure(go.Indicator(
            mode="gauge+number",
            value=prob,
            title={'text': "Churn Risk (%)"},
            gauge={
                'axis': {'range': [0, 100]},
                'bar': {'color': "black"},
                'steps': [
                    {'range': [0, 50], 'color': "green"},
                    {'range': [50, 70], 'color': "yellow"},
                    {'range': [70, 100], 'color': "red"}
                ],
            }
        ))

        gauge_json = json.dumps(fig, cls=plotly.utils.PlotlyJSONEncoder)

        return render_template_string(
            html_template,
            result=result,
            prob=round(prob, 2),
            gauge_json=gauge_json
        )

    return render_template_string(html_template)


if __name__ == "__main__":
    public_url = ngrok.connect(5000)
    print("🔥 PUBLIC URL:", public_url)
    app.run(port=5000)
# Out:
# Writing app.py

# %%
# !python app.py
# Out:
# 🔥 PUBLIC URL: NgrokTunnel: "https://5ff3b3202045.ngrok-free.app" -> "http://localhost:5000"
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [25/Jan/2026 08:26:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jan/2026 08:26:39] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jan/2026 08:27:03] "POST / HTTP/1.1" 200 -
# Exception ignored in: <module 'threading' from '/usr/lib/python3.12/threading.py'>
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1575, in _shutdown
#     def _shutdown():
#
# KeyboardInterrupt:
